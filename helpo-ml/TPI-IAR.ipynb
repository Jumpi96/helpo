# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %% [markdown]
# <img src="home-background.jpg" alt="Drawing" width="100%" height="100%" align="center"/>

# %% [markdown]
# <img src="PresentaciónTPI-IAR.png" alt="Drawing" width="100%" height="100%" align="center"/>

# %% [markdown]
# <img src="logo_principal.png" alt="Drawing" width="150" height="150"><span style="align:center"></span></img>
#
# <h1 align="center"> <span style="color:orange;font-size:50px">Aprendizaje automático en una plataforma con fines sociales</span></h1>
#
# <h2 align="center"> <span style="color:orange;font-size:40px">Inteligencia Artificial</span></h2>
#
# <h3 align="center"> <span style="color:orange;font-size:30px">Borello, Agustín - Ríos Julieta - Ulla, Gonzalo</span></h3>
#
# <h3 align="center"> <span style="color:orange;font-size:30px">Año 2018</span></h3>

# %% [markdown]
# <h1><span style="color:orange;font-size:50px">Agenda</span></h1>
# <ul>
#             <li>
#                 <p><span style="font-size:30px">Descripción del problema resuelto</span></p>
#             </li>
#             <li>
#                 <p><span style="font-size:30px">Explicación de la solución</span></p>
#                 <ul>
#                     <li><p><span style="font-size:30px">Fundamento teórico</span></p></li>
#                     <li><p><span style="font-size:30px">Librerías empleadas</span></p></li>
#                 </ul>
#             </li>
#             <li><p><span style="font-size:30px">Funcionalidad en Helpo</span></p></li>
#             <li><p><span style="font-size:30px">Análisis del comportamiento</span></p></li>
#     </ul>

# %% [markdown]
# <img src="logo_principal.png" alt="Drawing" width="150" height="150"><span style="align:center"></span></img>
#
# <h1 align="center"> <span style="color:orange;font-size:50px">Descripción del problema resuelto</span></h1>

# %%
from IPython.display import Image

# %%
Image(filename='home-background.jpg')

# %% [markdown]
# <h1 align="center"> <span style="color:orange;font-size:50px">¡Muchas gracias por su atención!</span></h1>
